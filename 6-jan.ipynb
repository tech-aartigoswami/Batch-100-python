# %%
# logical operator (and ,or,not)
and=it returns True when all condition are True otherwise false 
or = it returns True when any condition become true otherwise false
not = it reverse the the return true =false and false = true

# %%
condition statement(if else elif,multipal condition ,nested condition)

# %%
if condition statement

# %%
n= 20
if n>30:
    print("ha hai")
else:
    print("nhi hai ")
# Out:
# nhi hai

# %%
num1 = 20
num2 = 30
if(num1>num2):
    print("ha hai")# pass
else:
    print("nhi hai")
# Out:
# nhi hai

# %%
## and or not
num1 = 20
num2 = 30
if not(num1>num2):
    print("ha hai")# pass
else:
    print("nhi hai")
# Out:
# ha hai

# %%
res = not(num1>num2)
print(res)
# Out:
# True

# %%
num1 = 20
num2 = 30
if(num1>10)and(num2>num1):
    print("ha hai")# pass
else:
    print("nhi hai")
# Out:
# ha hai

# %%
num1 = 20
num2 = 30
if(num1>10)or(num2>num1):
    print("ha hai")# pass
else:
    print("nhi hai")
# Out:
# ha hai

# %%
n1 = 10 
n2 =100
if (n1>40) and (100>50) or (56>n2) and (n2>n1):
    print("ha hai")
else:
    print("nhi hai")
# Out:
# nhi hai

# %%
r = (num1>10)or(num2>num1)
print(r)
# Out:
# True

# %%
#4. membership operator(in ,not in)
email = "ysdev@gmail.com"
if "@gmail.com"in email:
    print("hai")
else:
    print("nhi hai")
# Out:
# hai

# %%
#4. membership operator(in ,not in)
email = "ysdev@gmail.com"
if "@gmail.com"not in email:
    print("hai")
else:
    print("nhi hai")
# Out:
# nhi hai

# %%
#questions
num1 = 5
num2 = 8
if(5>3)and(8>6):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
n1 = 10
n2 = 7
if(n1<5)or(n2>4):
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
# greater then 10 and less then 100.
n1 = 10
n2 =100
if(n1<50)and(n2>50):
    print("True")
# Out:
# True

# %%
n = 31
if n%2 == 0:
    print("odd")
else:
    print("even")
# Out:
# even

# %%
n1 = 3
n2 = 4
n3 = 5
if (n1>n2):
    print("n1")
if (n2>n3):
    print("n2")
else:
    print(n3, "greatest number")
# Out:
# 5 greatest number

# %%
name = "aarti"
if "a" in name:
    print("present vovel in name")
else:
    print("vovel is not in name")
# Out:
# present vovel in name

# %%
name = "aarti"
if "a"in name or "e"in name or "i"in name or "o" in name:
    print("present vovel in name")
else:
    print("vovel is not in name")
# Out:
# present vovel in name

# %%
#

# %%
# 6. assinment operator
# n = 20 
# n = n+20 # standard method
# print(n)


n= 20
n+=10 # shorthand method
print(n)
# Out:
# 30

# %%
# multiple  if
num = 100
if num >50:
    print("yes-1")
if num >50:
    print("yes-1")
else:
    print("no")
# Out:
# yes-1
# yes-1

# %%
num = 100
if num >50:
    print("yes-1")
if num >50:
    print("yes-2")
elif num > 38:
# multipal elif use nhi kar sakte uper condition true ho to
    print("yes-3") 
    
else:
    print("no")
# Out:
# yes-1
# yes-2

# %%
num = 100
if num >50:
    print("yes-1")
if num >50:
    print("yes-2")
elif num > 38:
# multipal elif use nhi kar sakte uper condition true ho to
    print("yes-3") 
elif num >110:
    print("yes-4")
else:
    print("no")
# Out:
# yes-1
# yes-2
