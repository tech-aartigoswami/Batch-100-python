# %%
print('hello data science')
# Out:
# hello data science

# %%
a = 12
print(a)
a =  "aarti"
print(a)
# Out:
# 12
# aarti

# %%
# cannot use any symbol
_ = "aarti"
print(_)
# Out:
# aarti

# %%
# cannot use whitespace
user_name = "aarti"
print(username)
# Out:
# aarti

# %%
# cannot use any keyword
if = "aarti"
print(if)

# %%
# write a program to add two num

num1 = 20
num2 = 30
result = num1+num2
print(result)
# Out:
# 50

# %%
num1 = 20
num2 = 30
result = num1+num2
print(f"sum of {num1} and {num2} is : {result}")
# Out:
# sum of 20 and 30 is : 50

# %%
num1 = 20
num2 = 30
result = num1+num2
print("sum of",num1, "and", num2,"is:",result)
print(type(result))
# Out:
# sum of 20 and 30 is: 50
# <class 'int'>

# %%
# wap to add three numbers.
# wab to add four numbers.
# wap to multiplication two number.
# wab to add two numbers and result of those numbers multiipiy 6.

# %%
# wap to add three numbers.
num1 = 10
num2 = 20
num3 = 30
result = num1+num2+num3
print(result)
print(type(result))
# Out:
# 60
# <class 'int'>

# %%
# wab to add four numbers.
num1 = 30
num2 = 40
num3 = 10
num4 = 4
res = num1+num2+num3+num4
print(f"sum of {num1},{num2},{num3} and {num4} is :{res}")
# Out:
# sum of 30,40,10 and 4 is :84

# %%
# wap to multiplication two numbe
num1 = 5
num2 = 5
res = num1*num2
print(res)
# Out:
# 25

# %%
 # wab to add two numbers and result of those numbers multiipiy 6.
num1 = 11
num2 = 13
print(f"res = {(num1 + num2)* 6}")
# Out:
# res = 144

# %%
# wab to add two numbers and result of those numbers division
num1 = 24
num2 = 23
res = (num1+num2) / 5
print(res)
print(type(res))
# Out:
# 9.4
# <class 'float'>
