# %%
num1 = 7
num2 = 11
res =int(num1/num2)
print(res)
# Out:
# 0

# %% [markdown]
# ### comparision operator
# - (==,>,<,>=,<=,!=)

# %%
self

# %%
num1 =  56
num2 = 55
res = num1>num2
print(res)
# Out:
# True

# %%
num1 =  56
num2 = 55
res = num1==num2
print(res)
# Out:
# False

# %%
num1 =  56
num2 = 55
res = num1>=num2
print(res)
# Out:
# True

# %%
user1 = "aman"
user2 = "Aman"
res = user1>user2
print(res)
# Out:
# True

# %%
num1 = 27
num2 = 43
num3 = 24
res = num1<num2>num3
print(res)
# Out:
# True

# %%
name1 = "aarti"
name2 = "mannu"
res = name1==name2
print(res)
# Out:
# False

# %%
num1 = 2
num2 = 3
res = num1!=num2
print(res)
# Out:
# True
